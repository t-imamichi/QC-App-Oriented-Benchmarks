# %% [markdown]
# ### QED-C Application-Oriented Benchmarks - Qiskit Version
# The notebook contains a suite of application-oriented benchmarks for the Qiskit API.
# Configure and run the cell below with the desired execution settings.
# Then execute the remaining cells, each containing one benchmark program.

# %%
min_qubits=2
max_qubits=8
skip_qubits=1
max_circuits=3
num_shots=10000

backend_id="ibm_brisbane"
# backend_id="test_eagle_us-east"
# backend_id="statevector_sampler"

hub="ibm-q-internal"; group="dev-qiskit"; project="primitives"
provider_backend = None
exec_options = {
    "optimization_level": 3,
    "use_sessions": True,
    "sampler_options": {
        "dynamical_decoupling": {
            "enable": True,
            "sequence_type": "XpXm",
        },
        "twirling": {"enable_measure": True},
        # "execution": {"rep_delay": 0.0005},
    }
}

# # ==========================
# # *** If using IBMQ hardware, run this once to authenticate
# from qiskit import IBMQ
# IBMQ.save_account('YOUR_API_TOKEN_HERE')

# # *** If you are part of an IBMQ group, set hub, group, and project name here
# hub="YOUR_HUB_NAME"; group="YOUR_GROUP_NAME"; project="YOUR_PROJECT_NAME"

# # *** This example shows how to specify an IBMQ backend using a known "backend_id"
# exec_options = { "optimization_level":3, "use_sessions":True, "resilience_level":1}
# backend_id="ibmq_belem"

# # ==========================
# # *** If using Azure Quantum, use this hub identifier and specify the desired backend_id
# # Identify your resources with env variables AZURE_QUANTUM_RESOURCE_ID and AZURE_QUANTUM_LOCATION
# hub="azure-quantum"; group="open"; project="QED-C App-Oriented Benchmarks - Qiskit Version"
# backend_id="<YOUR_BACKEND_NAME_HERE>"

# # ==========================
# The remaining examples illustrate other backend execution options

# # An example using IonQ provider
# from qiskit_ionq import IonQProvider
# provider = IonQProvider()   # Be sure to set the QISKIT_IONQ_API_TOKEN environment variable
# provider_backend = provider.get_backend("ionq_qpu")
# backend_id="ionq_qpu"

# # An example using BlueQubit provider (backend_id=CPU/QPU, device=cpu/qpu)
# import os, bluequbit, _common.executors.bluequbit_executor as bluequbit_executor
# provider_backend = bluequbit.init()
# backend_id="BlueQubit-CPU"
# exec_options = { "executor": bluequbit_executor.run, "device":"cpu" }

# # An example using a typical custom provider backend (e.g. AQT simulator)
# import os
# from qiskit_aqt_provider import AQTProvider
# provider = AQTProvider(os.environ.get('AQT_ACCESS_KEY'))    # get your key from environment
# provider_backend = provider.backends.aqt_qasm_simulator_noise_1
# backend_id="aqt_qasm_simulator_noise_1"

# # Fire Opal can be used to manage executions on other backends, as illustrated here
# import _common.executors.fire_opal_executor as fire_opal_executor
# from _common.executors.fire_opal_executor import FireOpalBackend
# ibm_backend_id = "ibmq_jakarta"
# backend_id = f"fire_opal_{ibm_backend_id}"
# provider_backend = FireOpalBackend(ibm_backend_id=ibm_backend_id, hub=hub, group=group, project=project, token=token)
# exec_options = {"executor": fire_opal_executor.run}

# %%
# Custom optimization options can be specified in this cell (below is an example)

# # Example of pytket Transformer
# import _common.transformers.tket_optimiser as tket_optimiser
# exec_options.update({ "optimization_level": 0, "layout_method":'sabre', "routing_method":'sabre', "transformer": tket_optimiser.high_optimisation })

# # Define a custom noise model to be used during execution
# import _common.custom.custom_qiskit_noise_model as custom_qiskit_noise_model
# exec_options.update({ "noise_model": custom_qiskit_noise_model.my_noise_model() })

# # Example of mthree error mitigation
# import _common.postprocessors.mthree.mthree_em as mthree_em
# exec_options.update({ "postprocessor": mthree_em.get_mthree_handlers(backend_id, provider_backend) })

# %% [markdown]
# ### Deutsch-Jozsa

# %%
import sys
sys.path.insert(1, "deutsch-jozsa/qiskit")
import dj_benchmark
dj_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Deutsch-Jozsa Benchmark Program - Qiskit
# ... execution starting at Sep 20, 2024 07:05:23 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# ... using Qiskit Runtime channel='ibm_quantum' instance='ibm-q-internal/dev-qiskit/primitives'
# ... execute using Sampler on backend_id='test_eagle_us-east' with options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XpXm', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=Unset, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [2] circuits with num_qubits = 3
#   ... transpiling with optimization_level=3
#   ... transpiling with optimization_level=3
# ************
# Executing [2] circuits with num_qubits = 4
#   ... transpiling with optimization_level=3
#   ... transpiling with optimization_level=3
# ************
# Executing [2] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 7, 0.083
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 7, 0.071, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.002, 19.242, 0.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.528, 0.001, 11.541 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.247, 0.005
#
#   ... transpiling with optimization_level=3
#   ... transpiling with optimization_level=3
# ************
# Executing [2] circuits with num_qubits = 6
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.088
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 8, 0.071, 1.5
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 18.119, 0.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.51, 0.001, 13.116 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.132, 0.009
#
#   ... transpiling with optimization_level=3
#   ... transpiling with optimization_level=3
# ************
# Executing [2] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 8, 0.077, 2.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.0, 17.759, 0.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.42, 0.001, 12.035 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.064, 0.002
#
#   ... transpiling with optimization_level=3
#   ... transpiling with optimization_level=3
# ************
# Executing [2] circuits with num_qubits = 8
#   ... transpiling with optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.1
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.076, 2.5
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 20.407, 0.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.59, 0.001, 14.394 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.026, 0.0
#
#   ... transpiling with optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 10, 0.107
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 10, 0.079, 3.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.001, 16.376, 0.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.682, 0.001, 11.482 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.018, 0.002

# %% [markdown]
# ### Bernstein-Vazirani - Method 1

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (1) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 14:44:37 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 6, 0.111
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 6, 0.091, 1.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 933.647, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 876.946, 0.001, 45.848 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.968, 0.957
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 7, 0.141
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 7, 0.106, 1.667
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.003, 337.259, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 292.962, 0.001, 38.942 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.949, 0.942
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 7, 0.118
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 7, 0.083, 1.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.005, 33.655, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.885, 0.001, 27.854 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.927, 0.922
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.157
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 8, 0.107, 2.667
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.003, 31.773, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.764, 0.001, 24.79 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.875, 0.871
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 7, 0.127
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 7, 0.082, 2.333
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.003, 30.294, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 2.037, 0.001, 24.727 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.886, 0.884
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.156
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8, 0.1, 3.333
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.002, 29.135, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.768, 0.001, 24.159 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.825, 0.823
#
# ... execution complete at Sep 18, 2024 15:03:17 UTC in 1119.349 secs
#
# Sample Circuit:
#         ┌───┐      ░ ┌─────┐ ░ ┌───┐      ░ ┌─┐
# q337_0: ┤ H ├──────░─┤0    ├─░─┤ H ├──────░─┤M├────────────
#         ├───┤      ░ │     │ ░ ├───┤      ░ └╥┘┌─┐
# q337_1: ┤ H ├──────░─┤1    ├─░─┤ H ├──────░──╫─┤M├─────────
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║ └╥┘┌─┐
# q337_2: ┤ H ├──────░─┤2    ├─░─┤ H ├──────░──╫──╫─┤M├──────
#         ├───┤      ░ │  Uf │ ░ ├───┤      ░  ║  ║ └╥┘┌─┐
# q337_3: ┤ H ├──────░─┤3    ├─░─┤ H ├──────░──╫──╫──╫─┤M├───
#         ├───┤      ░ │     │ ░ ├───┤      ░  ║  ║  ║ └╥┘┌─┐
# q337_4: ┤ H ├──────░─┤4    ├─░─┤ H ├──────░──╫──╫──╫──╫─┤M├
#         ├───┤┌───┐ ░ │     │ ░ ├───┤┌───┐ ░  ║  ║  ║  ║ └╥┘
# q337_5: ┤ X ├┤ H ├─░─┤5    ├─░─┤ H ├┤ X ├─░──╫──╫──╫──╫──╫─
#         └───┘└───┘ ░ └─────┘ ░ └───┘└───┘ ░  ║  ║  ║  ║  ║
#  c22: 5/═════════════════════════════════════╩══╩══╩══╩══╩═
#                                              0  1  2  3  4
#
# Quantum Oracle 'Uf' =
#
# q338_0: ──────────
#
# q338_1: ──■───────
#           │
# q338_2: ──┼───────
#           │
# q338_3: ──┼───────
#           │
# q338_4: ──┼────■──
#         ┌─┴─┐┌─┴─┐
# q338_5: ┤ X ├┤ X ├
#         └───┘└───┘

# %% [markdown]
# ### Bernstein-Vazirani - Method 2

# %%
import sys
sys.path.insert(1, "bernstein-vazirani/qiskit")
import bv_benchmark
bv_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Bernstein-Vazirani (2) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:03:18 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 10, 0.162
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 12, 0.135, 1.333
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.003, 107.99, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 59.204, 0.001, 40.527 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.975, 0.967
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 11, 0.125
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 12, 0.111, 1.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.001, 31.975, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 2.122, 0.001, 25.939 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.962, 0.957
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 16, 0.159
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 19, 0.128, 2.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 44.647, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.717, 0.001, 39.193 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.955, 0.952
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 18, 0.147
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 21, 0.12, 2.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 40.427, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.78, 0.001, 34.985 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.938, 0.936
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 21, 0.148
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 25, 0.119, 2.333
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.002, 34.71, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.68, 0.001, 26.479 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.941, 0.94
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 25, 0.163
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 30, 0.128, 3.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.002, 35.47, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.92, 0.001, 29.0 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.928, 0.928
#
# ... execution complete at Sep 18, 2024 15:08:57 UTC in 339.016 secs
#
# Sample Circuit:
#                    ░ ┌───┐     ┌───┐┌─┐     ┌───┐     ┌───┐┌─┐     ┌─┐     ┌─┐»
# q641_0: ───────────░─┤ H ├──■──┤ H ├┤M├─|0>─┤ H ├──■──┤ H ├┤M├─|0>─┤M├─|0>─┤M├»
#         ┌───┐┌───┐ ░ └───┘┌─┴─┐└───┘└╥┘     └───┘┌─┴─┐└───┘└╥┘     └╥┘     └╥┘»
# q641_1: ┤ X ├┤ H ├─░──────┤ X ├──────╫───────────┤ X ├──────╫───────╫───────╫─»
#         └───┘└───┘ ░      └───┘      ║           └───┘      ║       ║       ║ »
#  c40: 5/═════════════════════════════╩══════════════════════╩═══════╩═══════╩═»
#                                      0                      1       2       3 »
# «             ┌───┐     ┌───┐┌─┐
# «q641_0: ─|0>─┤ H ├──■──┤ H ├┤M├─|0>─
# «             └───┘┌─┴─┐└───┘└╥┘
# «q641_1: ──────────┤ X ├──────╫──────
# «                  └───┘      ║
# « c40: 5/═════════════════════╩══════
# «                             4

# %% [markdown]
# ### Hidden Shift

# %%
import sys
sys.path.insert(1, "hidden-shift/qiskit")
import hs_benchmark
hs_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hidden Shift Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:08:59 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 8, 0.189
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 16, 0.091, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.004, 43.537, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 2.721, 0.001, 33.707 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.941, 0.921
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 8, 0.215
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 17, 0.089, 4.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.004, 26.834, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.503, 0.001, 20.163 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.926, 0.921
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 8, 0.22
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 17, 0.09, 6.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.007, 37.826, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.529, 0.001, 28.666 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.868, 0.866
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 8, 0.223
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 17, 0.092, 8.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.003, 35.086, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.898, 0.001, 27.427 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.84, 0.839
#
# ... execution complete at Sep 18, 2024 15:12:08 UTC in 188.782 secs
#
# Sample Circuit:
#         ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─────┐ ░ ┌───┐ ░ ┌─┐
# q902_0: ┤ H ├─░─┤0    ├─░─┤ H ├─░─┤0    ├─░─┤ H ├─░─┤M├───────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░ └╥┘┌─┐
# q902_1: ┤ H ├─░─┤1    ├─░─┤ H ├─░─┤1    ├─░─┤ H ├─░──╫─┤M├────────────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║ └╥┘┌─┐
# q902_2: ┤ H ├─░─┤2    ├─░─┤ H ├─░─┤2    ├─░─┤ H ├─░──╫──╫─┤M├─────────
#         ├───┤ ░ │  Uf │ ░ ├───┤ ░ │  Ug │ ░ ├───┤ ░  ║  ║ └╥┘┌─┐
# q902_3: ┤ H ├─░─┤3    ├─░─┤ H ├─░─┤3    ├─░─┤ H ├─░──╫──╫──╫─┤M├──────
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║ └╥┘┌─┐
# q902_4: ┤ H ├─░─┤4    ├─░─┤ H ├─░─┤4    ├─░─┤ H ├─░──╫──╫──╫──╫─┤M├───
#         ├───┤ ░ │     │ ░ ├───┤ ░ │     │ ░ ├───┤ ░  ║  ║  ║  ║ └╥┘┌─┐
# q902_5: ┤ H ├─░─┤5    ├─░─┤ H ├─░─┤5    ├─░─┤ H ├─░──╫──╫──╫──╫──╫─┤M├
#         └───┘ ░ └─────┘ ░ └───┘ ░ └─────┘ ░ └───┘ ░  ║  ║  ║  ║  ║ └╥┘
#  c55: 6/═════════════════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                                      0  1  2  3  4  5
#
# Quantum Oracle 'Uf' =
#
# q903_0: ──────■──────
#         ┌───┐ │ ┌───┐
# q903_1: ┤ X ├─■─┤ X ├
#         ├───┤   ├───┤
# q903_2: ┤ X ├─■─┤ X ├
#         └───┘ │ └───┘
# q903_3: ──────■──────
#
# q903_4: ──■──────────
#           │
# q903_5: ──■──────────
#
#
# Quantum Oracle 'Ug' =
#
# q904_0: ─■─
#          │
# q904_1: ─■─
#
# q904_2: ─■─
#          │
# q904_3: ─■─
#
# q904_4: ─■─
#          │
# q904_5: ─■─

# %% [markdown]
# ### Quantum Fourier Transform - Method 1

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (1) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:12:09 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ... number of gates, depth = 12, 8
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 19, 14
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 30, 22
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 9, 0.224
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 18, 0.211, 4.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.002, 50.282, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.73, 0.001, 40.954 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.962, 0.949
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 15, 0.376
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 35, 0.3, 12.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 42.763, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.619, 0.001, 36.002 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.639, 0.587
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 42, 32
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 57, 44
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 23, 0.474
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 58, 0.346, 24.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.002, 39.901, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.976, 0.001, 33.099 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.559, 0.529
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 33, 0.551
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 87, 0.376, 40.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 32.688, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.951, 0.001, 25.344 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.299, 0.277
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 73, 58
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 92, 74
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 45, 0.604
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 122, 0.396, 60.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 47.971, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.886, 0.001, 41.704 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.074, 0.059
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 59, 0.643
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 163, 0.409, 84.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.001, 42.179, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 2.237, 0.001, 34.916 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.042, 0.034
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 75, 0.675
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 210, 0.419, 112.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.003, 35.152, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.93, 0.001, 27.56 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.007, 0.003
#
# ... execution complete at Sep 18, 2024 15:17:39 UTC in 330.363 secs
#
# Sample Circuit:
#                ░ ┌───────┐ ░  ┌───────┐   ░ ┌──────────┐ ░ ┌─┐
# q1186_0: ──────░─┤0      ├─░──┤ Rz(π) ├───░─┤0         ├─░─┤M├────────────
#                ░ │       │ ░ ┌┴───────┴┐  ░ │          │ ░ └╥┘┌─┐
# q1186_1: ──────░─┤1      ├─░─┤ Rz(π/2) ├──░─┤1         ├─░──╫─┤M├─────────
#          ┌───┐ ░ │       │ ░ ├─────────┤  ░ │          │ ░  ║ └╥┘┌─┐
# q1186_2: ┤ X ├─░─┤2 qft_ ├─░─┤ Rz(π/4) ├──░─┤2 inv_qft ├─░──╫──╫─┤M├──────
#          ├───┤ ░ │       │ ░ ├─────────┤  ░ │          │ ░  ║  ║ └╥┘┌─┐
# q1186_3: ┤ X ├─░─┤3      ├─░─┤ Rz(π/8) ├──░─┤3         ├─░──╫──╫──╫─┤M├───
#          └───┘ ░ │       │ ░ ├─────────┴┐ ░ │          │ ░  ║  ║  ║ └╥┘┌─┐
# q1186_4: ──────░─┤4      ├─░─┤ Rz(π/16) ├─░─┤4         ├─░──╫──╫──╫──╫─┤M├
#                ░ └───────┘ ░ └──────────┘ ░ └──────────┘ ░  ║  ║  ║  ║ └╥┘
#   c70: 5/═══════════════════════════════════════════════════╩══╩══╩══╩══╩═
#                                                             0  1  2  3  4
#
# QFT Circuit =
#                ░                  ░                             ░            »
# q1187_0: ──────░──────────────────░─────────────────────────────░────────────»
#                ░                  ░                             ░            »
# q1187_1: ──────░──────────────────░─────────────────────────────░──────■─────»
#                ░                  ░                       ┌───┐ ░      │     »
# q1187_2: ──────░──────────────────░──────■──────────■─────┤ H ├─░──────┼─────»
#                ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░      │     »
# q1187_3: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░──────┼─────»
#          ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░ ┌────┴────┐»
# q1187_4: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─┤ Rz(π/8) ├»
#          └───┘ ░ └─────────┘      ░ └─────────┘                 ░ └─────────┘»
# «                                     ░                                   »
# «q1187_0: ────────────────────────────░──────■───────────■──────────■─────»
# «                               ┌───┐ ░      │           │          │     »
# «q1187_1: ─────■──────────■─────┤ H ├─░──────┼───────────┼──────────┼─────»
# «              │     ┌────┴────┐└───┘ ░      │           │     ┌────┴────┐»
# «q1187_2: ─────┼─────┤ Rz(π/2) ├──────░──────┼───────────┼─────┤ Rz(π/4) ├»
# «         ┌────┴────┐└─────────┘      ░      │      ┌────┴────┐└─────────┘»
# «q1187_3: ┤ Rz(π/4) ├─────────────────░──────┼──────┤ Rz(π/8) ├───────────»
# «         └─────────┘                 ░ ┌────┴─────┐└─────────┘           »
# «q1187_4: ────────────────────────────░─┤ Rz(π/16) ├──────────────────────»
# «                                     ░ └──────────┘                      »
# «                    ┌───┐ ░
# «q1187_0: ─────■─────┤ H ├─░─
# «         ┌────┴────┐└───┘ ░
# «q1187_1: ┤ Rz(π/2) ├──────░─
# «         └─────────┘      ░
# «q1187_2: ─────────────────░─
# «                          ░
# «q1187_3: ─────────────────░─
# «                          ░
# «q1187_4: ─────────────────░─
# «                          ░
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1188_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1188_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1188_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1188_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1188_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1188_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1188_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1188_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1188_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1188_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1188_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1188_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1188_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1188_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1188_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Quantum Fourier Transform - Method 2

# %%
import sys
sys.path.insert(1, "quantum-fourier-transform/qiskit")
import qft_benchmark
qft_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Quantum Fourier Transform (2) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:17:41 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ... number of gates, depth = 9, 5
# ************
# Executing [3] circuits with num_qubits = 3
# ... number of gates, depth = 15, 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 6, 0.143
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 8, 0.262, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.002, 38.08, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 10.217, 0.001, 22.206 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.915, 0.887
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# ... number of gates, depth = 22, 12
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 9, 0.25
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 16, 0.327, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.001, 32.069, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.616, 0.001, 26.508 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.769, 0.736
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# ... number of gates, depth = 30, 17
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 13, 0.333
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 27, 0.357, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.0, 49.406, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.64, 0.001, 43.412 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.73, 0.712
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# ... number of gates, depth = 39, 23
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 18, 0.4
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 41, 0.382, 20.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.002, 38.044, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.943, 0.001, 30.706 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.576, 0.562
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# ... number of gates, depth = 49, 30
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 24, 0.455
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 58, 0.398, 30.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.001, 33.774, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.847, 0.001, 28.304 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.223, 0.211
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# ... number of gates, depth = 60, 38
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 31, 0.5
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 78, 0.41, 42.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.001, 39.087, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.469, 0.001, 33.35 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.104, 0.097
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 39, 0.538
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 101, 0.42, 56.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.002, 48.125, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.71, 0.001, 42.962 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.014, 0.01
#
# ... execution complete at Sep 18, 2024 15:22:58 UTC in 317.246 secs
#
# Sample Circuit:
#          ┌───┐┌─────────┐ ┌──────────┐┌─┐
# q1914_0: ┤ H ├┤ Rz(12π) ├─┤0         ├┤M├────────────
#          ├───┤└┬────────┤ │          │└╥┘┌─┐
# q1914_1: ┤ H ├─┤ Rz(6π) ├─┤1         ├─╫─┤M├─────────
#          ├───┤ ├────────┤ │          │ ║ └╥┘┌─┐
# q1914_2: ┤ H ├─┤ Rz(3π) ├─┤2 inv_qft ├─╫──╫─┤M├──────
#          ├───┤┌┴────────┴┐│          │ ║  ║ └╥┘┌─┐
# q1914_3: ┤ H ├┤ Rz(3π/2) ├┤3         ├─╫──╫──╫─┤M├───
#          ├───┤├──────────┤│          │ ║  ║  ║ └╥┘┌─┐
# q1914_4: ┤ H ├┤ Rz(3π/4) ├┤4         ├─╫──╫──╫──╫─┤M├
#          └───┘└──────────┘└──────────┘ ║  ║  ║  ║ └╥┘
#   c91: 5/══════════════════════════════╩══╩══╩══╩══╩═
#                                        0  1  2  3  4
#
# Inverse QFT Circuit =
#          ┌───┐                                                  ░      »
# q1915_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#          └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q1915_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#               └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q1915_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                           └──────────┘┌────┴─────┐      │       ░      »
# q1915_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                       └──────────┘┌─────┴─────┐ ░      »
# q1915_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                   └───────────┘ ░      »
# «                                              ░                              »
# «q1915_0: ─────────────────────────────────────░──────────────────────────────»
# «                                              ░                              »
# «q1915_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «         ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q1915_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «         └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q1915_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                     └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q1915_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                 └──────────┘ ░                  └──────────┘»
# «          ░                   ░       ░
# «q1915_0: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1915_1: ─░───────────────────░───────░─
# «          ░                   ░       ░
# «q1915_2: ─░───────────────────░───────░─
# «          ░ ┌───┐             ░       ░
# «q1915_3: ─░─┤ H ├─────■───────░───────░─
# «          ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q1915_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «          ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Grover

# %%
import sys
sys.path.insert(1, "grovers/qiskit")
import grovers_benchmark
grovers_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Grover's Search Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:22:59 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 13, 0.116
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 13, 0.123, 2.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.003, 34.74, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 1.977, 0.001, 25.822 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.907, 0.876
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 25, 0.085
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 51, 0.308, 24.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.005, 37.609, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 2.264, 0.001, 30.767 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.605, 0.422
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 38, 0.07
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 167, 0.393, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.007, 32.77, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.653, 0.001, 27.777 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.437, 0.306
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 50, 0.057
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 607, 0.372, 288.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.011, 58.223, 3.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.607, 0.001, 50.388 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.045, 0.004
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 66, 0.052
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1699, 0.404, 1008.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.012, 86.989, 5.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 2.04, 0.001, 79.02 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.03, 0.0
#
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 130, 0.042
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 8787, 0.419, 5280.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.025, 25.789, 0.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 0, 0, 0 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0, 0
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 93, 0.043
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 3323, 0.423, 2240.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.038, 102.598, 4.667 secs
# Average Transpiling, Validating, Running Times for group 7 = 0, 0, 0 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.018, 0.0
#
# ... execution complete at Sep 18, 2024 15:30:05 UTC in 425.311 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ »
# q2527_0: ┤ H ├─░─┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2527_1: ┤ H ├─░─┤1        ├┤1          ├─░─┤1        ├┤1          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2527_2: ┤ H ├─░─┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2527_3: ┤ H ├─░─┤3        ├┤3          ├─░─┤3        ├┤3          ├─░─»
#          ├───┤ ░ │         ││           │ ░ │         ││           │ ░ »
# q2527_4: ┤ H ├─░─┤4        ├┤4          ├─░─┤4        ├┤4          ├─░─»
#          └───┘ ░ └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░ »
#  c112: 5/══════════════════════════════════════════════════════════════»
#                                                                        »
# «         ┌─────────┐┌───────────┐ ░ ┌─────────┐┌───────────┐ ░ ┌─┐
# «q2527_0: ┤0        ├┤0          ├─░─┤0        ├┤0          ├─░─┤M├────────────
# «         │         ││           │ ░ │         ││           │ ░ └╥┘┌─┐
# «q2527_1: ┤1        ├┤1          ├─░─┤1        ├┤1          ├─░──╫─┤M├─────────
# «         │         ││           │ ░ │         ││           │ ░  ║ └╥┘┌─┐
# «q2527_2: ┤2 oracle ├┤2 diffuser ├─░─┤2 oracle ├┤2 diffuser ├─░──╫──╫─┤M├──────
# «         │         ││           │ ░ │         ││           │ ░  ║  ║ └╥┘┌─┐
# «q2527_3: ┤3        ├┤3          ├─░─┤3        ├┤3          ├─░──╫──╫──╫─┤M├───
# «         │         ││           │ ░ │         ││           │ ░  ║  ║  ║ └╥┘┌─┐
# «q2527_4: ┤4        ├┤4          ├─░─┤4        ├┤4          ├─░──╫──╫──╫──╫─┤M├
# «         └─────────┘└───────────┘ ░ └─────────┘└───────────┘ ░  ║  ║  ║  ║ └╥┘
# « c112: 5/═══════════════════════════════════════════════════════╩══╩══╩══╩══╩═
# «                                                                0  1  2  3  4
#
# Oracle =
#          ┌───┐                ░ ┌───┐
# q2534_0: ┤ X ├───────■────────░─┤ X ├
#          ├───┤       │        ░ ├───┤
# q2534_1: ┤ X ├───────■────────░─┤ X ├
#          └───┘       │        ░ └───┘
# q2534_2: ────────────■────────░──────
#          ┌───┐       │        ░ ┌───┐
# q2534_3: ┤ X ├───────■────────░─┤ X ├
#          ├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤
# q2534_4: ┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├
#          └───┘└───┘└───┘└───┘ ░ └───┘
#
# Diffuser =
#          ┌───┐┌───┐                ░ ┌───┐┌───┐
# q2535_0: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2535_1: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2535_2: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤       │        ░ ├───┤├───┤
# q2535_3: ┤ H ├┤ X ├───────■────────░─┤ X ├┤ H ├
#          ├───┤├───┤┌───┐┌─┴─┐┌───┐ ░ ├───┤├───┤
# q2535_4: ┤ H ├┤ X ├┤ H ├┤ X ├┤ H ├─░─┤ X ├┤ H ├
#          └───┘└───┘└───┘└───┘└───┘ ░ └───┘└───┘

# %% [markdown]
# ### Phase Estimation

# %%
import sys
sys.path.insert(1, "phase-estimation/qiskit")
import pe_benchmark
pe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Phase Estimation Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:30:06 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 16, 0.316
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 19, 0.261, 6.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.011, 53.097, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 4.735, 0.001, 41.181 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.835, 0.78
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 27, 0.353
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 31, 0.3, 12.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.011, 69.447, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.653, 0.001, 58.522 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.789, 0.759
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 41, 0.377
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 45, 0.326, 19.333
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.012, 29.21, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 2.646, 0.001, 23.105 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.631, 0.606
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 58, 0.395
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 63, 0.348, 29.333
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.014, 30.054, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.629, 0.001, 24.613 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.458, 0.441
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 78, 0.408
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 84, 0.365, 41.333
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.036, 36.931, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.982, 0.001, 29.168 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.115, 0.101
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 101, 0.418
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 108, 0.378, 55.333
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.018, 45.439, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.926, 0.001, 38.769 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.006, 0.0
#
# ... execution complete at Sep 18, 2024 15:35:12 UTC in 305.618 secs
#
# Sample Circuit:
#           ┌───┐ ░                              ░ ┌──────────┐ ░ ┌─┐
# q17842_0: ┤ H ├─░─────────────────────────■────░─┤0         ├─░─┤M├─────────
#           ├───┤ ░                         │    ░ │          │ ░ └╥┘┌─┐
# q17842_1: ┤ H ├─░──────────────────■──────┼────░─┤1         ├─░──╫─┤M├──────
#           ├───┤ ░                  │      │    ░ │  inv_qft │ ░  ║ └╥┘┌─┐
# q17842_2: ┤ H ├─░───────────■──────┼──────┼────░─┤2         ├─░──╫──╫─┤M├───
#           ├───┤ ░           │      │      │    ░ │          │ ░  ║  ║ └╥┘┌─┐
# q17842_3: ┤ H ├─░────■──────┼──────┼──────┼────░─┤3         ├─░──╫──╫──╫─┤M├
#           ├───┤ ░ ┌──┴──┐┌──┴──┐┌──┴──┐┌──┴──┐ ░ └──────────┘ ░  ║  ║  ║ └╥┘
# q17842_4: ┤ X ├─░─┤ U^1 ├┤ U^2 ├┤ U^4 ├┤ U^8 ├─░──────────────░──╫──╫──╫──╫─
#           └───┘ ░ └─────┘└─────┘└─────┘└─────┘ ░              ░  ║  ║  ║  ║
#   c130: 4/═══════════════════════════════════════════════════════╩══╩══╩══╩═
#                                                                  0  1  2  3
#
# Phase Operator 'U' =
#    ┌────────┐
# q: ┤ P(π/2) ├
#    └────────┘
#
# Inverse QFT Circuit =
#           ┌───┐                                                  ░      »
# q17933_0: ┤ H ├─────■───────────■───────────■────────────■───────░──────»
#           └───┘┌────┴─────┐     │           │            │       ░ ┌───┐»
# q17933_1: ─────┤ Rz(-π/2) ├─────┼───────────┼────────────┼───────░─┤ H ├»
#                └──────────┘┌────┴─────┐     │            │       ░ └───┘»
# q17933_2: ─────────────────┤ Rz(-π/4) ├─────┼────────────┼───────░──────»
#                            └──────────┘┌────┴─────┐      │       ░      »
# q17933_3: ─────────────────────────────┤ Rz(-π/8) ├──────┼───────░──────»
#                                        └──────────┘┌─────┴─────┐ ░      »
# q17933_4: ─────────────────────────────────────────┤ Rz(-π/16) ├─░──────»
#                                                    └───────────┘ ░      »
# «                                               ░                              »
# «q17933_0: ─────────────────────────────────────░──────────────────────────────»
# «                                               ░                              »
# «q17933_1: ─────■───────────■───────────■───────░──────────────────────────────»
# «          ┌────┴─────┐     │           │       ░ ┌───┐                        »
# «q17933_2: ┤ Rz(-π/2) ├─────┼───────────┼───────░─┤ H ├─────■───────────■──────»
# «          └──────────┘┌────┴─────┐     │       ░ └───┘┌────┴─────┐     │      »
# «q17933_3: ────────────┤ Rz(-π/4) ├─────┼───────░──────┤ Rz(-π/2) ├─────┼──────»
# «                      └──────────┘┌────┴─────┐ ░      └──────────┘┌────┴─────┐»
# «q17933_4: ────────────────────────┤ Rz(-π/8) ├─░──────────────────┤ Rz(-π/4) ├»
# «                                  └──────────┘ ░                  └──────────┘»
# «           ░                   ░       ░
# «q17933_0: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q17933_1: ─░───────────────────░───────░─
# «           ░                   ░       ░
# «q17933_2: ─░───────────────────░───────░─
# «           ░ ┌───┐             ░       ░
# «q17933_3: ─░─┤ H ├─────■───────░───────░─
# «           ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# «q17933_4: ─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
# «           ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### HHL Linear Solver

# %%
import sys
sys.path.insert(1, "hhl/qiskit")
import hhl_benchmark

hhl_benchmark.verbose=False

hhl_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1, use_best_widths=True,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# HHL Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:35:13 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing 3 circuits with 4 qubits, using 1 input qubits and 1 clock qubits
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing 3 circuits with 5 qubits, using 1 input qubits and 2 clock qubits
# ERROR: failed to execute result_handler for circuit 4 3006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 4 1006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 4 2006
# ... exception = invalid literal for int() with base 2: ''
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 76, 0.252
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 114, 0.307, 50.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.004, 37.07, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 2.326, 0.001, 25.432 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0, 0
#
# optimization_level=3
# ************
# Executing 3 circuits with 6 qubits, using 1 input qubits and 3 clock qubits
# ERROR: failed to execute result_handler for circuit 5 1006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 5 2006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 6 1006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ************
# Executing 3 circuits with 7 qubits, using 2 input qubits and 2 clock qubits
# ERROR: failed to execute result_handler for circuit 5 3006
# ... exception = invalid literal for int() with base 2: ''
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 148, 0.263
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 212, 0.317, 100.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.004, 71.824, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.884, 0.001, 66.527 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0, 0
#
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 6 2006
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 6 3006
# ... exception = invalid literal for int() with base 2: ''
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 225, 0.275
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 315, 0.323, 152.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.006, 65.932, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.825, 0.001, 59.11 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0, 0
#
# optimization_level=3
# ************
# Executing 3 circuits with 8 qubits, using 2 input qubits and 3 clock qubits
# ERROR: failed to execute result_handler for circuit 7 2012
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 7 1012
# ... exception = invalid literal for int() with base 2: ''
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 7 3072
# ... exception = invalid literal for int() with base 2: ''
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 151, 0.26
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 272, 0.329, 176.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.006, 58.907, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 2.029, 0.001, 52.014 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0, 0
#
# optimization_level=3
# ERROR: failed to execute result_handler for circuit 8 1024
# ... exception = invalid literal for int() with base 2: ''
# ERROR: failed to execute result_handler for circuit 8 3024
# ... exception = invalid literal for int() with base 2: ''
# ERROR: failed to execute result_handler for circuit 8 2006
# ... exception = invalid literal for int() with base 2: ''
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 237, 0.262
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 411, 0.331, 264.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.006, 58.083, 3.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.898, 0.001, 52.607 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0, 0
#
# ... execution complete at Sep 18, 2024 15:40:51 UTC in 337.553 secs
#
# Sample Circuit:
#          ┌───┐ ░ ┌───────────┐ ░          ░                           ░        »
#   input: ┤ X ├─░─┤0          ├─░──────────░───────────────────────────░────────»
#          └───┘ ░ │           │ ░          ░                           ░        »
#  in_anc: ──────░─┤1          ├─░──────────░───────────────────────────░────────»
#          ┌───┐ ░ │  e^{0iAt} │ ░ ┌──────┐ ░      ┌──────────┐         ░ ┌─────┐»
#   clock: ┤ H ├─░─┤2          ├─░─┤ IQFT ├─░──────┤0         ├─────────░─┤ QFT ├»
#          └───┘ ░ │           │ ░ └──────┘ ░      │  INV_ROT │┌─┐      ░ └─────┘»
# ancilla: ──────░─┤3          ├─░──────────░──|0>─┤1         ├┤M├─|0>──░────────»
#                ░ └───────────┘ ░          ░      └──────────┘└╥┘      ░        »
#  c140: 1/═════════════════════════════════════════════════════╬════════════════»
#                                                               ║                »
#  c141: 1/═════════════════════════════════════════════════════╩════════════════»
#                                                               0                »
# «          ░ ┌────────────┐ ░       ░ ┌─┐
# «  input: ─░─┤0           ├─░───────░─┤M├
# «          ░ │            │ ░       ░ └╥┘
# « in_anc: ─░─┤1           ├─░───────░──╫─
# «          ░ │  e^{-0iAt} │ ░ ┌───┐ ░  ║
# «  clock: ─░─┤2           ├─░─┤ H ├─░──╫─
# «          ░ │            │ ░ └───┘ ░  ║
# «ancilla: ─░─┤3           ├─░───────░──╫─
# «          ░ └────────────┘ ░       ░  ║
# « c140: 1/═════════════════════════════╩═
# «                                      0
# « c141: 1/═══════════════════════════════
# «
#
# U Circuit =
#         ┌───┐            ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q18237: ┤ X ├────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#         └───┘  ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q18238: ───────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#                └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q18239: ──────■─────────────────────────────────────────────────────────────»
#         ┌───┐ │P(3π/2)   ┌───┐                                              »
# q18240: ┤ X ├─■──────────┤ X ├──────────────────────────────────────────────»
#         └───┘            └───┘                                              »
# «         ┌──────────┐┌───────────┐                             ┌───┐»
# «q18237: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «        ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q18238: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «        └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q18239: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «q18240: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «        ┌───────────┐                  ┌───────────┐┌──────────┐┌───────────┐»
# «q18237: ┤ Rz(-3π/2) ├──■────────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «        └───┬───┬───┘  │            │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q18238: ────┤ X ├──────■────────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «            └───┘      │            │      └───┘     └────────┘  └──────────┘»
# «q18239: ───────────────┼───■────────┼────────────────────────────────────────»
# «                     ┌─┴─┐ │P(-π) ┌─┴─┐                                      »
# «q18240: ─────────────┤ X ├─■──────┤ X ├──────────────────────────────────────»
# «                     └───┘        └───┘                                      »
# «                        ┌──────────┐┌───────────┐                             »
# «q18237: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «        ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q18238: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «        └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q18239: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q18240: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «        ┌───┐┌───────────┐┌───┐     ┌───┐
# «q18237: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «        └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q18238: ──■────────────────────┤ X ├─────
# «                               └───┘
# «q18239: ─────────────────────────────────
# «
# «q18240: ─────────────────────────────────
# «
#
# U^-1 Circuit =
#         ┌───┐             ┌───┐   ┌───────────┐┌──────────┐┌───────────┐     »
# q18245: ┤ X ├─────■───────┤ X ├───┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├──■──»
#         └───┘   ┌─┴─┐   ┌─┴───┴──┐└┬──────────┤└┬────────┬┘└───────────┘┌─┴─┐»
# q18246: ────────┤ X ├───┤ Rz(-π) ├─┤ Ry(-π/2) ├─┤ Rz(-π) ├──────────────┤ X ├»
#                 └───┘   └────────┘ └──────────┘ └────────┘              └───┘»
# q18247: ──────■──────────────────────────────────────────────────────────────»
#         ┌───┐ │P(-3π/2)   ┌───┐                                              »
# q18248: ┤ X ├─■───────────┤ X ├──────────────────────────────────────────────»
#         └───┘             └───┘                                              »
# «         ┌──────────┐┌───────────┐                             ┌───┐»
# «q18245: ─┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────┤ X ├»
# «        ┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐└─┬─┘»
# «q18246: ┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├──■──»
# «        └───────────┘  └────────┘ └───┘└──────────┘└──────────┘     »
# «q18247: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «q18248: ────────────────────────────────────────────────────────────»
# «                                                                    »
# «        ┌───────────┐                 ┌───────────┐┌──────────┐┌───────────┐»
# «q18245: ┤ Rz(-3π/2) ├──■───────────■──┤ Rz(-3π/2) ├┤ Ry(-π/2) ├┤ Rz(-3π/2) ├»
# «        └───┬───┬───┘  │           │  └───┬───┬───┘└┬────────┬┘└┬──────────┤»
# «q18246: ────┤ X ├──────■───────────■──────┤ X ├─────┤ Rz(-π) ├──┤ Ry(-π/2) ├»
# «            └───┘      │           │      └───┘     └────────┘  └──────────┘»
# «q18247: ───────────────┼───■───────┼────────────────────────────────────────»
# «                     ┌─┴─┐ │P(π) ┌─┴─┐                                      »
# «q18248: ─────────────┤ X ├─■─────┤ X ├──────────────────────────────────────»
# «                     └───┘       └───┘                                      »
# «                        ┌──────────┐┌───────────┐                             »
# «q18245: ────────────■───┤ Rx(-π/2) ├┤ Rz(-3π/2) ├──■──────────────────────────»
# «        ┌────────┐┌─┴─┐┌┴──────────┤└─┬────────┬┘┌─┴─┐┌──────────┐┌──────────┐»
# «q18246: ┤ Rz(-π) ├┤ X ├┤ Rz(-7π/4) ├──┤ Rx(-π) ├─┤ X ├┤ Ry(-π/2) ├┤ Rx(-π/4) ├»
# «        └────────┘└───┘└───────────┘  └────────┘ └───┘└──────────┘└──────────┘»
# «q18247: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q18248: ──────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «        ┌───┐┌───────────┐┌───┐     ┌───┐
# «q18245: ┤ X ├┤ Rz(-3π/2) ├┤ X ├──■──┤ X ├
# «        └─┬─┘└───────────┘└───┘┌─┴─┐└───┘
# «q18246: ──■────────────────────┤ X ├─────
# «                               └───┘
# «q18247: ─────────────────────────────────
# «
# «q18248: ─────────────────────────────────
# «
#
# QFT Circuit =
#         ┌───┐ ░
# q18244: ┤ H ├─░─
#         └───┘ ░
#
# Inverse QFT Circuit =
#         ┌───┐ ░
# q18241: ┤ H ├─░─
#         └───┘ ░
#
# Hamiltonian Phase Estimation Circuit =
#   ... too large!
#
# Controlled Rotation Circuit =
#
# q18242: ─────────────────■────────────────────■──
#         ┌─────────────┐┌─┴─┐┌──────────────┐┌─┴─┐
# q18243: ┤ Ry(0.77628) ├┤ X ├┤ Ry(-0.27092) ├┤ X ├
#         └─────────────┘└───┘└──────────────┘└───┘

# %% [markdown]
# ### Amplitude Estimation

# %%
import sys
sys.path.insert(1, "amplitude-estimation/qiskit")
import ae_benchmark
ae_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Amplitude Estimation Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:40:52 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [2] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.422
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 58, 0.387, 29.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.012, 45.724, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 2.774, 0.001, 35.406 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.635, 0.27
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 208, 0.432
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 165, 0.398, 84.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.01, 60.303, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.921, 0.001, 53.82 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.569, 0.266
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 479, 0.436
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 375, 0.404, 192.667
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.01, 42.958, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.881, 0.001, 36.554 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.256, 0.019
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 1017, 0.438
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 836, 0.407, 426.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.012, 66.607, 3.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.649, 0.001, 57.67 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.114, 0.012
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2086, 0.439
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 1701, 0.408, 868.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.019, 72.784, 3.667 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.766, 0.001, 65.66 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.061, 0.002
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4214, 0.44
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 3417, 0.409, 1744.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.031, 108.22, 5.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.968, 0.001, 99.841 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.031, 0.003
#
# ... execution complete at Sep 18, 2024 15:48:11 UTC in 439.192 secs
#
# Sample Circuit:
#           ┌───┐                         ┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q20187_0: ┤ H ├─────────────────────────┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#           ├───┤         ┌──────┐┌──────┐│      ││      ││      ││      │ ░ »
# q20187_1: ┤ H ├─────────┤0     ├┤0     ├┤      ├┤      ├┤      ├┤      ├─░─»
#           ├───┤ ┌──────┐│      ││      ││      ││      ││      ││      │ ░ »
# q20187_2: ┤ H ├─┤0     ├┤      ├┤      ├┤  c_Q ├┤  c_Q ├┤  c_Q ├┤  c_Q ├─░─»
#           ├───┴┐│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q20186_0: ┤0   ├┤1 c_Q ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#           │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q20186_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├┤2     ├─░─»
#           └────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘└──────┘ ░ »
#   c177: 3/═════════════════════════════════════════════════════════════════»
#                                                                            »
# «          ┌──────────┐ ░ ┌─┐
# «q20187_0: ┤0         ├─░─┤M├──────
# «          │          │ ░ └╥┘┌─┐
# «q20187_1: ┤1 inv_qft ├─░──╫─┤M├───
# «          │          │ ░  ║ └╥┘┌─┐
# «q20187_2: ┤2         ├─░──╫──╫─┤M├
# «          └──────────┘ ░  ║  ║ └╥┘
# «q20186_0: ─────────────░──╫──╫──╫─
# «                       ░  ║  ║  ║
# «q20186_1: ─────────────░──╫──╫──╫─
# «                       ░  ║  ║  ║
# «  c177: 3/════════════════╩══╩══╩═
# «                          0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q21449: ──■───
#         ┌─┴──┐
#    q_0: ┤0   ├
#         │  Q │
#    q_1: ┤1   ├
#         └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#                              ┌───┐
# q_0: ────────────────────────┤ X ├
#      ┌────────────┐┌───┐┌───┐└─┬─┘
# q_1: ┤ Ry(2.0624) ├┤ X ├┤ X ├──■──
#      └────────────┘└───┘└───┘
#
# Inverse QFT Circuit =
#           ┌───┐                         ░                   ░       ░
# q20194_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#           └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q20194_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#                └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q20194_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                            └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Monte Carlo

# %%
import sys
sys.path.insert(1, "monte-carlo/qiskit")
import mc_benchmark
mc_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Monte Carlo Sampling (2) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:48:13 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 202, 0.398
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 208, 0.372, 96.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.018, 36.103, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.9, 0.001, 28.752 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.537, 0.073
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 468, 0.401
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 479, 0.377, 224.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.011, 39.332, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.915, 0.001, 33.39 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.253, 0.011
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 997, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 1017, 0.38, 478.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.017, 52.348, 3.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.547, 0.001, 43.832 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.116, 0.002
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 2049, 0.402
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2086, 0.382, 982.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.057, 68.376, 3.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 2.058, 0.001, 61.673 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.058, 0.001
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 4144, 0.403
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 4214, 0.382, 1984.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.101, 98.227, 4.667 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.733, 0.001, 90.322 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.029, 0.005
#
# ... execution complete at Sep 18, 2024 15:54:02 UTC in 349.068 secs
#
# Sample Circuit:
#           ┌────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐┌──────┐ ░ »
# q22714_0: ┤0   ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├┤1     ├─░─»
#           │  A ││      ││      ││      ││      ││      ││      ││      │ ░ »
# q22714_1: ┤1   ├┤2     ├┤2     ├┤2     ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├┤2 c_Q ├─░─»
#           ├───┬┘│      ││  c_Q ││  c_Q ││      ││      ││      ││      │ ░ »
# q22715_0: ┤ H ├─┤  c_Q ├┤      ├┤      ├┤0     ├┤0     ├┤0     ├┤0     ├─░─»
#           ├───┤ │      ││      ││      │└──────┘└──────┘└──────┘└──────┘ ░ »
# q22715_1: ┤ H ├─┤      ├┤0     ├┤0     ├─────────────────────────────────░─»
#           ├───┤ │      │└──────┘└──────┘                                 ░ »
# q22715_2: ┤ H ├─┤0     ├─────────────────────────────────────────────────░─»
#           └───┘ └──────┘                                                 ░ »
#   c192: 3/═════════════════════════════════════════════════════════════════»
#                                                                            »
# «                       ░
# «q22714_0: ─────────────░──────────
# «                       ░
# «q22714_1: ─────────────░──────────
# «          ┌──────────┐ ░ ┌─┐
# «q22715_0: ┤0         ├─░─┤M├──────
# «          │          │ ░ └╥┘┌─┐
# «q22715_1: ┤1 inv_qft ├─░──╫─┤M├───
# «          │          │ ░  ║ └╥┘┌─┐
# «q22715_2: ┤2         ├─░──╫──╫─┤M├
# «          └──────────┘ ░  ║  ║ └╥┘
# «  c192: 3/════════════════╩══╩══╩═
# «                          0  1  2
#
# Controlled Quantum Operator 'cQ' =
#
# q24431: ──■───
#         ┌─┴──┐
#    q_0: ┤0   ├
#         │  Q │
#    q_1: ┤1   ├
#         └────┘
#
# Quantum Operator 'Q' =
#                     ┌───────┐┌───┐          ┌───┐     ┌────┐
# q_0: ───────────────┤0      ├┤ X ├───────■──┤ X ├─────┤0   ├
#      ┌───┐┌───┐┌───┐│  A_dg │├───┤┌───┐┌─┴─┐├───┤┌───┐│  A │
# q_1: ┤ X ├┤ Z ├┤ X ├┤1      ├┤ X ├┤ H ├┤ X ├┤ H ├┤ X ├┤1   ├
#      └───┘└───┘└───┘└───────┘└───┘└───┘└───┘└───┘└───┘└────┘
#
# Amplitude Generator 'A' =
#           ┌────┐┌────┐
# q24422_0: ┤0   ├┤0   ├
#           │  R ││  F │
# q24422_1: ┤1   ├┤1   ├
#           └────┘└────┘
#
# Distribution Generator 'R' =
#           ┌───┐
# q24423_0: ┤ H ├
#           └───┘
# q24423_1: ─────
#
#
# Function Generator 'F' =
#
# q24424_0: ──■──
#           ┌─┴─┐
# q24424_1: ┤ X ├
#           └───┘
#
# Inverse QFT Circuit =
#           ┌───┐                         ░                   ░       ░
# q22721_0: ┤ H ├─────■───────────■───────░───────────────────░───────░─
#           └───┘┌────┴─────┐     │       ░ ┌───┐             ░       ░
# q22721_1: ─────┤ Rz(-π/2) ├─────┼───────░─┤ H ├─────■───────░───────░─
#                └──────────┘┌────┴─────┐ ░ └───┘┌────┴─────┐ ░ ┌───┐ ░
# q22721_2: ─────────────────┤ Rz(-π/4) ├─░──────┤ Rz(-π/2) ├─░─┤ H ├─░─
#                            └──────────┘ ░      └──────────┘ ░ └───┘ ░

# %% [markdown]
# ### Hamiltonian Simulation - Method 1

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian Simulation Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 15:54:03 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 47, 0.246
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 46, 0.25, 15.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.01, 75.745, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 21.496, 0.001, 47.791 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.945, 0.89
#
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.268
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 71, 0.273, 30.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.012, 54.055, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.731, 0.001, 45.426 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.592, 0.495
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 82, 0.278
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 71, 0.3, 45.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.008, 34.727, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.799, 0.001, 26.671 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.498, 0.381
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 82, 0.282
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 71, 0.3, 60.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.016, 31.137, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.674, 0.001, 25.614 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.378, 0.248
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 82, 0.285
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 71, 0.312, 75.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.019, 36.755, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.576, 0.001, 30.7 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.372, 0.252
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 82, 0.287
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 71, 0.31, 90.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.021, 96.7, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.696, 0.001, 87.554 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.364, 0.261
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 82, 0.288
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 71, 0.318, 105.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.023, 56.807, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.902, 0.001, 50.267 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.452, 0.377
#
# ... execution complete at Sep 18, 2024 16:01:05 UTC in 421.829 secs
#
# Sample Circuit:
#           ┌───────────────┐┌─────────────┐┌─┐
# q25994_0: ┤0              ├┤0            ├┤M├───────────────
#           │               ││             │└╥┘┌─┐
# q25994_1: ┤1              ├┤1            ├─╫─┤M├────────────
#           │               ││             │ ║ └╥┘┌─┐
# q25994_2: ┤2              ├┤2            ├─╫──╫─┤M├─────────
#           │  InitialState ││  Heisenberg │ ║  ║ └╥┘┌─┐
# q25994_3: ┤3              ├┤3            ├─╫──╫──╫─┤M├──────
#           │               ││             │ ║  ║  ║ └╥┘┌─┐
# q25994_4: ┤4              ├┤4            ├─╫──╫──╫──╫─┤M├───
#           │               ││             │ ║  ║  ║  ║ └╥┘┌─┐
# q25994_5: ┤5              ├┤5            ├─╫──╫──╫──╫──╫─┤M├
#           └───────────────┘└─────────────┘ ║  ║  ║  ║  ║ └╥┘
#   c216: 6/═════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                            0  1  2  3  4  5
#   Initial State:
#           ┌───┐
# q25995_0: ┤ X ├
#           └───┘
# q25995_1: ─────
#           ┌───┐
# q25995_2: ┤ X ├
#           └───┘
# q25995_3: ─────
#           ┌───┐
# q25995_4: ┤ X ├
#           └───┘
# q25995_5: ─────
#
#   Hamiltonian (Heisenberg):
#            ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# q25996_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
#           ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# q25996_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
#           └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# q25996_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
#            ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# q25996_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
#            ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# q25996_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
#           ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# q25996_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
#           └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q25996_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q25996_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q25996_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q25996_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q25996_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q25996_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q25996_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q25996_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q25996_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q25996_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q25996_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q25996_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q25996_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░
# «q25996_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░
# «q25996_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░
# «q25996_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░
# «q25996_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░
# «q25996_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░
# «q25996_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░
#
# XXYYZZ =
#                      ┌───┐┌─────────────┐                    ┌───┐┌──────────┐
# q26489_0: ───────────┤ X ├┤ Rz(-1.4451) ├──■─────────────────┤ X ├┤ Rz(-π/2) ├
#           ┌─────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘└──────────┘
# q26489_1: ┤ Rz(π/2) ├──■───┤ Ry(1.4451) ├┤ X ├┤ Ry(-1.4451) ├──■──────────────
#           └─────────┘      └────────────┘└───┘└─────────────┘

# %% [markdown]
# ### Hamiltonian Simulation - Method 2

# %%
import sys
sys.path.insert(1, "hamiltonian-simulation/qiskit")
import hamiltonian_simulation_benchmark
hamiltonian_simulation_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, skip_qubits=skip_qubits,
                max_circuits=max_circuits, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Hamiltonian Simulation Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 16:01:07 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 2
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 2 qubit group = 47, 0.246
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 2 qubit group = 46, 0.25, 15.0
# Average Creation, Elapsed, Execution Time for the 2 qubit group = 0.011, 40.051, 2.0 secs
# Average Transpiling, Validating, Running Times for group 2 = 2.217, 0.001, 30.073 secs
# Average Hellinger, Normalized Fidelity for the 2 qubit group = 0.915, 0.834
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 3 qubit group = 72, 0.268
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 3 qubit group = 71, 0.273, 30.0
# Average Creation, Elapsed, Execution Time for the 3 qubit group = 0.012, 57.657, 2.0 secs
# Average Transpiling, Validating, Running Times for group 3 = 1.775, 0.001, 50.996 secs
# Average Hellinger, Normalized Fidelity for the 3 qubit group = 0.654, 0.43
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 5
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 82, 0.278
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 71, 0.3, 45.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 0.015, 43.249, 2.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 1.818, 0.001, 37.398 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.632, 0.43
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 7
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 5 qubit group = 82, 0.282
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 5 qubit group = 71, 0.3, 60.0
# Average Creation, Elapsed, Execution Time for the 5 qubit group = 0.017, 35.145, 2.0 secs
# Average Transpiling, Validating, Running Times for group 5 = 1.9, 0.001, 28.164 secs
# Average Hellinger, Normalized Fidelity for the 5 qubit group = 0.297, 0.0
#
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 82, 0.285
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 71, 0.312, 75.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.045, 36.432, 2.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 1.733, 0.001, 29.929 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.35, 0.124
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 82, 0.287
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 71, 0.31, 90.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.021, 54.818, 2.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 1.865, 0.001, 47.946 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.335, 0.159
#
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 82, 0.288
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 71, 0.318, 105.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.023, 42.771, 2.0 secs
# Average Transpiling, Validating, Running Times for group 8 = 2.042, 0.001, 37.04 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.368, 0.246
#
# ... execution complete at Sep 18, 2024 16:07:00 UTC in 353.443 secs
#
# Sample Circuit:
#           ┌───────────────┐┌─────────────┐┌─┐
# q27137_0: ┤0              ├┤0            ├┤M├───────────────
#           │               ││             │└╥┘┌─┐
# q27137_1: ┤1              ├┤1            ├─╫─┤M├────────────
#           │               ││             │ ║ └╥┘┌─┐
# q27137_2: ┤2              ├┤2            ├─╫──╫─┤M├─────────
#           │  InitialState ││  Heisenberg │ ║  ║ └╥┘┌─┐
# q27137_3: ┤3              ├┤3            ├─╫──╫──╫─┤M├──────
#           │               ││             │ ║  ║  ║ └╥┘┌─┐
# q27137_4: ┤4              ├┤4            ├─╫──╫──╫──╫─┤M├───
#           │               ││             │ ║  ║  ║  ║ └╥┘┌─┐
# q27137_5: ┤5              ├┤5            ├─╫──╫──╫──╫──╫─┤M├
#           └───────────────┘└─────────────┘ ║  ║  ║  ║  ║ └╥┘
#   c237: 6/═════════════════════════════════╩══╩══╩══╩══╩══╩═
#                                            0  1  2  3  4  5
#   Initial State:
#           ┌───┐
# q27138_0: ┤ X ├
#           └───┘
# q27138_1: ─────
#           ┌───┐
# q27138_2: ┤ X ├
#           └───┘
# q27138_3: ─────
#           ┌───┐
# q27138_4: ┤ X ├
#           └───┘
# q27138_5: ─────
#
#   Hamiltonian (Heisenberg):
#            ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# q27139_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
#           ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# q27139_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
#           └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# q27139_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
#            ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# q27139_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
#            ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# q27139_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
#           ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# q27139_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
#           └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q27139_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q27139_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q27139_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q27139_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q27139_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q27139_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q27139_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q27139_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░ »
# «q27139_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─»
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░ »
# «q27139_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─»
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─»
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░ »
# «q27139_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─»
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░ »
# «q27139_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─»
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░ »
# «q27139_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─»
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░ »
# «           ┌──────────────┐ ┌─────────────┐  ░ ┌─────────┐            ░
# «q27139_0: ─┤ Rx(-0.03073) ├─┤ Rz(0.01103) ├──░─┤0        ├────────────░─
# «          ┌┴──────────────┤┌┴─────────────┴┐ ░ │  XXYYZZ │┌─────────┐ ░
# «q27139_1: ┤ Rx(0.0031026) ├┤ Rz(-0.069446) ├─░─┤1        ├┤0        ├─░─
# «          └┬──────────────┤└┬──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░
# «q27139_2: ─┤ Rx(0.042928) ├─┤ Rz(0.062098) ├─░─┤0        ├┤1        ├─░─
# «           ├──────────────┤ ├──────────────┤ ░ │  XXYYZZ │├─────────┤ ░
# «q27139_3: ─┤ Rx(0.046275) ├─┤ Rz(0.068745) ├─░─┤1        ├┤0        ├─░─
# «           ├─────────────┬┘ ├──────────────┤ ░ ├─────────┤│  XXYYZZ │ ░
# «q27139_4: ─┤ Rx(0.05929) ├──┤ Rz(0.028751) ├─░─┤0        ├┤1        ├─░─
# «          ┌┴─────────────┴┐┌┴──────────────┤ ░ │  XXYYZZ │└─────────┘ ░
# «q27139_5: ┤ Rx(-0.049933) ├┤ Rz(0.0070841) ├─░─┤1        ├────────────░─
# «          └───────────────┘└───────────────┘ ░ └─────────┘            ░
#
# XXYYZZ =
#                      ┌───┐┌─────────────┐                    ┌───┐┌──────────┐
# q27632_0: ───────────┤ X ├┤ Rz(-1.4451) ├──■─────────────────┤ X ├┤ Rz(-π/2) ├
#           ┌─────────┐└─┬─┘└┬────────────┤┌─┴─┐┌─────────────┐└─┬─┘└──────────┘
# q27632_1: ┤ Rz(π/2) ├──■───┤ Ry(1.4451) ├┤ X ├┤ Ry(-1.4451) ├──■──────────────
#           └─────────┘      └────────────┘└───┘└─────────────┘

# %% [markdown]
# ### VQE - Method 1

# %%
import sys
sys.path.insert(1, "vqe/qiskit")
import vqe_benchmark
vqe_num_shots=4098
vqe_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits,
                max_circuits=max_circuits, num_shots=vqe_num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# VQE Simulation (1) Benchmark Program - Qiskit
# ... execution starting at Sep 18, 2024 16:07:01 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [3] circuits with num_qubits = 4
# optimization_level=3
# optimization_level=3
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 6
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 4 qubit group = 5, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 4 qubit group = 76, 0.533, 56.0
# Average Creation, Elapsed, Execution Time for the 4 qubit group = 6.118, 50.121, 4.0 secs
# Average Transpiling, Validating, Running Times for group 4 = 2.034, 0.001, 37.442 secs
# Average Hellinger, Normalized Fidelity for the 4 qubit group = 0.498, 0.39
#
# optimization_level=3
# ************
# Executing [3] circuits with num_qubits = 8
# optimization_level=3
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 6 qubit group = 10, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 6 qubit group = 341, 0.63, 272.0
# Average Creation, Elapsed, Execution Time for the 6 qubit group = 0.028, 50.941, 5.0 secs
# Average Transpiling, Validating, Running Times for group 6 = 2.524, 0.001, 41.947 secs
# Average Hellinger, Normalized Fidelity for the 6 qubit group = 0.078, 0.013
#
# optimization_level=3
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 8 qubit group = 26, 0.0
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 8 qubit group = 1543, 0.692, 1280.0
# Average Creation, Elapsed, Execution Time for the 8 qubit group = 0.044, 94.16, 8.667 secs
# Average Transpiling, Validating, Running Times for group 8 = 1.939, 0.001, 87.194 secs
# Average Hellinger, Normalized Fidelity for the 8 qubit group = 0.054, 0.0
#
# ... execution complete at Sep 18, 2024 16:11:00 UTC in 238.711 secs
#
# Sample Circuit:
#           ┌─────┐┌────────────────────┐┌────────────────────┐»
# q27740_0: ┤0    ├┤0                   ├┤0                   ├»
#           │     ││                    ││                    │»
# q27740_1: ┤1    ├┤1                   ├┤1                   ├»
#           │  Hf ││  Cluster Op (0, 1) ││  Cluster Op (2, 3) │»
# q27740_2: ┤2    ├┤2                   ├┤2                   ├»
#           │     ││                    ││                    │»
# q27740_3: ┤3    ├┤3                   ├┤3                   ├»
#           └─────┘└────────────────────┘└────────────────────┘»
#   meas: 4/═══════════════════════════════════════════════════»
#                                                              »
# «          ┌──────────────────────────┐ ░ ┌─┐
# «q27740_0: ┤0                         ├─░─┤M├─────────
# «          │                          │ ░ └╥┘┌─┐
# «q27740_1: ┤1                         ├─░──╫─┤M├──────
# «          │  Cluster Op (0, 1, 2, 3) │ ░  ║ └╥┘┌─┐
# «q27740_2: ┤2                         ├─░──╫──╫─┤M├───
# «          │                          │ ░  ║  ║ └╥┘┌─┐
# «q27740_3: ┤3                         ├─░──╫──╫──╫─┤M├
# «          └──────────────────────────┘ ░  ║  ║  ║ └╥┘
# «  meas: 4/════════════════════════════════╩══╩══╩══╩═
# «                                          0  1  2  3
#
# Hartree Fock Generator 'Hf' =
#      ┌───┐
# q_0: ┤ X ├
#      └───┘
# q_1: ─────
#      ┌───┐
# q_2: ┤ X ├
#      └───┘
# q_3: ─────
#
#
# Cluster Operator Example 'Cluster Op' =
#      ┌──────────────────────────────────────────────────────────────────────┐
# q_0: ┤0                                                                     ├
#      │                                                                      │
# q_1: ┤1                                                                     ├
#      │  exp(-it (YXXX + XYXX + XXYX + YYYX + XXXY + YYXY + YXYY + XYYY))(1) │
# q_2: ┤2                                                                     ├
#      │                                                                      │
# q_3: ┤3                                                                     ├
#      └──────────────────────────────────────────────────────────────────────┘

# %% [markdown]
# ### Shor - Method 1

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=1,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (1) Benchmark - Qiskit
# Max number of qubits 8 is too low to run method 1 of Shor's Order Finding

# %% [markdown]
# ### Shor - Method 2

# %%
import sys
sys.path.insert(1, "shors/qiskit")
import shors_benchmark
shors_benchmark.run(min_qubits=min_qubits, max_qubits=max_qubits, max_circuits=1, num_shots=num_shots,
                method=2,
                backend_id=backend_id, provider_backend=provider_backend,
                hub=hub, group=group, project=project, exec_options=exec_options)
# Out:
# Shor's Order Finding (2) Benchmark - Qiskit
# ... execution starting at Sep 18, 2024 16:11:01 UTC
# setting instance ibm-q-internal/dev-qiskit/primitives
# sampler.options=SamplerOptions(_VERSION=2, max_execution_time=Unset, environment=EnvironmentOptions(log_level='WARNING', callback=None, job_tags=None, private=False), simulator=SimulatorOptions(noise_model=Unset, seed_simulator=Unset, coupling_map=Unset, basis_gates=Unset), default_shots=Unset, dynamical_decoupling=DynamicalDecouplingOptions(enable=True, sequence_type='XX', extra_slack_distribution=Unset, scheduling_method=Unset), execution=SamplerExecutionOptionsV2(init_qubits=Unset, rep_delay=0.0005, meas_type=Unset), twirling=TwirlingOptions(enable_gates=Unset, enable_measure=True, num_randomizations=Unset, shots_per_randomization=Unset, strategy=Unset), experimental=Unset)
# ************
# Executing [1] circuits with num_qubits = 7
# /Users/ima/envs/qiskit312/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/ima/envs/qiskit312/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# optimization_level=3
# /Users/ima/envs/qiskit312/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: divide by zero encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# /Users/ima/envs/qiskit312/lib/python3.12/site-packages/numpy/linalg/linalg.py:2180: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)
# ************
# Average Circuit Algorithmic Depth, ξ (xi) for the 7 qubit group = 881, 0.527
# Average Normalized Transpiled Depth, ξ (xi), 2q gates for the 7 qubit group = 2710, 0.429, 1488.0
# Average Creation, Elapsed, Execution Time for the 7 qubit group = 0.234, 148.788, 6.0 secs
# Average Transpiling, Validating, Running Times for group 7 = 3.001, 0.001, 127.905 secs
# Average Hellinger, Normalized Fidelity for the 7 qubit group = 0.108, 0.0
#
# ... execution complete at Sep 18, 2024 16:13:43 UTC in 161.26 secs
#
# Sample Circuit:
#                 ░  ┌───┐ ┌───┐┌──────────┐┌──────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
#   q28677: ──────░──┤ X ├─┤ H ├┤0         ├┤ P(0) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
#           ┌───┐ ░  └─╥─┘ └───┘│          │└──╥───┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# q28678_0: ┤ X ├─░────╫────────┤1         ├───╫──────────╫──╫──░────╫────────»
#           └───┘ ░    ║        │          │   ║          ║  ║  ░    ║        »
# q28678_1: ──────░────╫────────┤2         ├───╫──────────╫──╫──░────╫────────»
#                 ░    ║        │          │   ║          ║  ║  ░    ║        »
# q28679_0: ──────░────╫────────┤3 C-U^256 ├───╫──────────╫──╫──░────╫────────»
#                 ░    ║        │          │   ║          ║  ║  ░    ║        »
# q28679_1: ──────░────╫────────┤4         ├───╫──────────╫──╫──░────╫────────»
#                 ░    ║        │          │   ║          ║  ║  ░    ║        »
# q28679_2: ──────░────╫────────┤5         ├───╫──────────╫──╫──░────╫────────»
#                 ░    ║        │          │   ║          ║  ║  ░    ║        »
# q28679_3: ──────░────╫────────┤6         ├───╫──────────╫──╫──░────╫────────»
#                 ░    ║        └──────────┘┌──╨──┐       ║  ║  ░    ║        »
#   c244: 4/═══════════╬════════════════════╡ 0x0 ╞═══════╩══╬═══════╬════════»
#                   ┌──╨──┐                 └─────┘       0  ║    ┌──╨──┐     »
#   c245: 1/════════╡ 0x1 ╞══════════════════════════════════╩════╡ 0x1 ╞═════»
#                   └─────┘                                  0    └─────┘     »
# «          ┌─────────┐┌──────┐┌────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐┌────────┐»
# «  q28677: ┤0        ├┤ P(0) ├┤ P(π/2) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├┤0       ├»
# «          │         │└──╥───┘└───╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘│        │»
# «q28678_0: ┤1        ├───╫────────╫───────────╫──╫──░────╫────────┤1       ├»
# «          │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q28678_1: ┤2        ├───╫────────╫───────────╫──╫──░────╫────────┤2       ├»
# «          │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q28679_0: ┤3 C-U^16 ├───╫────────╫───────────╫──╫──░────╫────────┤3 C-U^4 ├»
# «          │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q28679_1: ┤4        ├───╫────────╫───────────╫──╫──░────╫────────┤4       ├»
# «          │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q28679_2: ┤5        ├───╫────────╫───────────╫──╫──░────╫────────┤5       ├»
# «          │         │   ║        ║           ║  ║  ░    ║        │        │»
# «q28679_3: ┤6        ├───╫────────╫───────────╫──╫──░────╫────────┤6       ├»
# «          └─────────┘┌──╨──┐  ┌──╨──┐        ║  ║  ░    ║        └────────┘»
# «  c244: 4/═══════════╡ 0x0 ╞══╡ 0x1 ╞════════╩══╬═══════╬══════════════════»
# «                     └─────┘  └─────┘        1  ║    ┌──╨──┐               »
# «  c245: 1/══════════════════════════════════════╩════╡ 0x1 ╞═══════════════»
# «                                                0    └─────┘               »
# «          ┌──────┐┌────────┐┌────────┐┌─────────┐┌───┐┌─┐┌─┐ ░  ┌───┐ ┌───┐»
# «  q28677: ┤ P(0) ├┤ P(π/4) ├┤ P(π/2) ├┤ P(3π/4) ├┤ H ├┤M├┤M├─░──┤ X ├─┤ H ├»
# «          └──╥───┘└───╥────┘└───╥────┘└────╥────┘└───┘└╥┘└╥┘ ░  └─╥─┘ └───┘»
# «q28678_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «             ║        ║         ║          ║           ║  ║  ░    ║        »
# «q28678_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «             ║        ║         ║          ║           ║  ║  ░    ║        »
# «q28679_0: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «             ║        ║         ║          ║           ║  ║  ░    ║        »
# «q28679_1: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «             ║        ║         ║          ║           ║  ║  ░    ║        »
# «q28679_2: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «             ║        ║         ║          ║           ║  ║  ░    ║        »
# «q28679_3: ───╫────────╫─────────╫──────────╫───────────╫──╫──░────╫────────»
# «          ┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐        ║  ║  ░    ║        »
# «  c244: 4/╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞════════╩══╬═══════╬════════»
# «          └─────┘  └─────┘   └─────┘    └─────┘        2  ║    ┌──╨──┐     »
# «  c245: 1/════════════════════════════════════════════════╩════╡ 0x1 ╞═════»
# «                                                          0    └─────┘     »
# «          ┌────────┐┌──────┐┌────────┐┌────────┐┌─────────┐┌────────┐»
# «  q28677: ┤0       ├┤ P(0) ├┤ P(π/8) ├┤ P(π/4) ├┤ P(3π/8) ├┤ P(π/2) ├»
# «          │        │└──╥───┘└───╥────┘└───╥────┘└────╥────┘└───╥────┘»
# «q28678_0: ┤1       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          │        │   ║        ║         ║          ║         ║     »
# «q28678_1: ┤2       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          │        │   ║        ║         ║          ║         ║     »
# «q28679_0: ┤3 C-U^2 ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          │        │   ║        ║         ║          ║         ║     »
# «q28679_1: ┤4       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          │        │   ║        ║         ║          ║         ║     »
# «q28679_2: ┤5       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          │        │   ║        ║         ║          ║         ║     »
# «q28679_3: ┤6       ├───╫────────╫─────────╫──────────╫─────────╫─────»
# «          └────────┘┌──╨──┐  ┌──╨──┐   ┌──╨──┐    ┌──╨──┐   ┌──╨──┐  »
# «  c244: 4/══════════╡ 0x0 ╞══╡ 0x1 ╞═══╡ 0x2 ╞════╡ 0x3 ╞═══╡ 0x4 ╞══»
# «                    └─────┘  └─────┘   └─────┘    └─────┘   └─────┘  »
# «  c245: 1/═══════════════════════════════════════════════════════════»
# «                                                                     »
# «          ┌─────────┐┌─────────┐┌─────────┐┌───┐┌─┐┌─┐
# «  q28677: ┤ P(5π/8) ├┤ P(3π/4) ├┤ P(7π/8) ├┤ H ├┤M├┤M├
# «          └────╥────┘└────╥────┘└────╥────┘└───┘└╥┘└╥┘
# «q28678_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «               ║          ║          ║           ║  ║
# «q28678_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «               ║          ║          ║           ║  ║
# «q28679_0: ─────╫──────────╫──────────╫───────────╫──╫─
# «               ║          ║          ║           ║  ║
# «q28679_1: ─────╫──────────╫──────────╫───────────╫──╫─
# «               ║          ║          ║           ║  ║
# «q28679_2: ─────╫──────────╫──────────╫───────────╫──╫─
# «               ║          ║          ║           ║  ║
# «q28679_3: ─────╫──────────╫──────────╫───────────╫──╫─
# «            ┌──╨──┐    ┌──╨──┐    ┌──╨──┐        ║  ║
# «  c244: 4/══╡ 0x5 ╞════╡ 0x6 ╞════╡ 0x7 ╞════════╩══╬═
# «            └─────┘    └─────┘    └─────┘        3  ║
# «  c245: 1/══════════════════════════════════════════╩═
# «                                                    0
#
# Controlled Ua Operator 'cUa' =
#           ┌─────────────┐      ┌─────────────────┐
#   q28812: ┤0            ├─■──■─┤0                ├
#           │             │ │  │ │                 │
# q28813_0: ┤1            ├─X──┼─┤1                ├
#           │             │ │  │ │                 │
# q28813_1: ┤2            ├─┼──X─┤2                ├
#           │             │ │  │ │                 │
# q28814_0: ┤3 cMULTamodN ├─X──┼─┤3 inv_cMULTamodN ├
#           │             │    │ │                 │
# q28814_1: ┤4            ├────X─┤4                ├
#           │             │      │                 │
# q28815_0: ┤5            ├──────┤5                ├
#           │             │      │                 │
# q28815_1: ┤6            ├──────┤6                ├
#           └─────────────┘      └─────────────────┘
#
# Controlled Multiplier Operator 'cMULTamodN' =
#                    ┌─────────────┐┌─────────────┐
#   q28836: ─────────┤0            ├┤0            ├────────────
#                    │             ││             │
# q28837_0: ─────────┤1            ├┤             ├────────────
#                    │             ││             │
# q28837_1: ─────────┤             ├┤1            ├────────────
#           ┌───────┐│             ││             │┌──────────┐
# q28838_0: ┤0      ├┤2 ccφADDmodN ├┤2 ccφADDmodN ├┤0         ├
#           │       ││             ││             ││          │
# q28838_1: ┤1 qft_ ├┤3            ├┤3            ├┤1 inv_qft ├
#           │       ││             ││             ││          │
# q28838_2: ┤2      ├┤4            ├┤4            ├┤2         ├
#           └───────┘│             ││             │└──────────┘
#   q28839: ─────────┤5            ├┤5            ├────────────
#                    └─────────────┘└─────────────┘
#
# Controlled Modular Adder Operator 'ccphiamodN' =
#                                                                                »
# q28848_0: ────■─────────────────────────────────────────────────────────■──────»
#               │                                                         │      »
# q28848_1: ────■─────────────────────────────────────────────────────────■──────»
#           ┌───┴───┐┌───────────┐┌──────────┐     ┌───────┐┌───────┐┌────┴─────┐»
# q28849_0: ┤0      ├┤0          ├┤0         ├─────┤0      ├┤0      ├┤0         ├»
#           │       ││           ││          │     │       ││       ││          │»
# q28849_1: ┤1 φADD ├┤1 inv_φADD ├┤1 inv_qft ├─────┤1 qft_ ├┤1 φADD ├┤1 φADD_dg ├»
#           │       ││           ││          │     │       ││       ││          │»
# q28849_2: ┤2      ├┤2          ├┤2         ├──■──┤2      ├┤2      ├┤2         ├»
#           └───────┘└───────────┘└──────────┘┌─┴─┐└───────┘└───┬───┘└──────────┘»
#   q28850: ──────────────────────────────────┤ X ├─────────────■────────────────»
#                                             └───┘                              »
# «
# «q28848_0: ────────────────────────────────────────■────
# «                                                  │
# «q28848_1: ────────────────────────────────────────■────
# «          ┌──────────┐               ┌───────┐┌───┴───┐
# «q28849_0: ┤0         ├───────────────┤0      ├┤0      ├
# «          │          │               │       ││       │
# «q28849_1: ┤1 inv_qft ├───────────────┤1 qft_ ├┤1 φADD ├
# «          │          │┌───┐     ┌───┐│       ││       │
# «q28849_2: ┤2         ├┤ X ├──■──┤ X ├┤2      ├┤2      ├
# «          └──────────┘└───┘┌─┴─┐└───┘└───────┘└───────┘
# «  q28850: ─────────────────┤ X ├───────────────────────
# «                           └───┘
#
# Phi Adder Operator 'φADD' =
#        ┌──────┐
# q_0: ──┤ P(π) ├─
#      ┌─┴──────┴┐
# q_1: ┤ P(3π/2) ├
#      ├─────────┤
# q_2: ┤ P(3π/4) ├
#      └─────────┘
#
# QFT Circuit =
#                 ░                  ░                       ┌───┐ ░
# q28856_0: ──────░──────────────────░──────■──────────■─────┤ H ├─░─
#                 ░            ┌───┐ ░      │     ┌────┴────┐└───┘ ░
# q28856_1: ──────░──────■─────┤ H ├─░──────┼─────┤ Rz(π/2) ├──────░─
#           ┌───┐ ░ ┌────┴────┐└───┘ ░ ┌────┴────┐└─────────┘      ░
# q28856_2: ┤ H ├─░─┤ Rz(π/2) ├──────░─┤ Rz(π/4) ├─────────────────░─
#           └───┘ ░ └─────────┘      ░ └─────────┘                 ░

# %% [markdown]
# ### Combined Benchmark Results

# %%
import sys
sys.path.insert(1, "_common")
import metrics

# metrics.depth_base = 2
# metrics.QV = 0
# apps = [ "Hidden Shift", "Grover's Search", "Quantum Fourier Transform (1)", "Hamiltonian Simulation" ]
# backend_id='qasm_simulator'

metrics.plot_all_app_metrics(backend_id, do_all_plots=False, include_apps=None)
